# %% [markdown]
# ---
# toc: false
# comments: True
# layout: post
# title: ChatGPT Voice Assistant
# description: Voice assistant powered by my OpenAi API Key and Python
# courses: { compsci: {week: 3} }
# type: hacks
# ---

# %%
# import speech_recognition as sr
# import pyttsx3
# import openai
# import sounddevice
# import sys  # Import the sys module for exiting the program

# openai.api_key = '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'

# def SpeakText(command):
#     engine = pyttsx3.init()
#     engine.say(command)
#     engine.runAndWait()

# r = sr.Recognizer()

# def record_text():
#     while True:
#         try:
#             with sr.Microphone() as source2:
#                 print("I can hear you")
#                 audio2 = r.listen(source2)
#                 MyText = r.recognize_google(audio2)
#                 return MyText
#         except sr.RequestError as e:
#             print("Error requesting results; {0}".format(e))
#         except sr.UnknownValueError:
#             print("Something unexpected happened")

# def send_to_ChatGPT(messages, model="gpt3.5-turbo"):
#     response = openai.ChatCompletion.create(
#         model=model,
#         messages=messages,
#         max_tokens=100,
#         n=1,
#         temperature=0.7,
#     )

#     message = response.choices[0].message.content
#     messages.append({"role": "assistant", "content": message})
#     return message

# messages = [{"role": "user", "content": "Act like yourself"}]

# try:  # Use a try-except block to handle KeyboardInterrupt
#     while True:
#         text = record_text()
#         messages.append({"role": "user", "content": text})
#         response = send_to_ChatGPT(messages)
#         SpeakText(response)
#         print(response)
# except KeyboardInterrupt:
#     print("User stopped the program.")
#     sys.exit(0)  # Exit the program gracefully
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_403106/3814689512.py in <module>
#       2 import pyttsx3
#       3 import openai
# ----> 4 import sounddevice
#       5 import sys  # Import the sys module for exiting the program
#       6
#
# ~/.local/lib/python3.10/site-packages/sounddevice.py in <module>
#      69             break
#      70     else:
# ---> 71         raise OSError('PortAudio library not found')
#      72     _lib = _ffi.dlopen(_libname)
#      73 except OSError:
#
# OSError: PortAudio library not found

# %%
import openai
import pyttsx3
import speech_recognition as sr
import time

# Set key
openai.api_key = ""

#Set engine
engine = pyttsx3.init()

def transcribe_audio_to_text(filename):
    recognizer = sr.Recognizer()
    with sr.AudioFile(filename) as source:
        audio = recognizer.record(source)
    try:
        return recognizer.recognize_google(audio)
    except:
        print('Skipping unknown error')

def generate_response(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=4000,
        n=1,
        stop=None,
        temperature=0.5,
    )
    return response["choices"][0]["text"]

def speak_text(text):
    engine.say(text)
    engine.runAndWait()

def main():
    while True:
        # Wait for keyword
        print("Say 'Hello' to start ")
        with sr.Microphone() as source:
            recognizer = sr.Recognizer()
            audio = recognizer.listen(source)
            try:
                transcription = recognizer.recognize_google(audio)
                if transcription.lower() == "Hello":
                    # Record
                    filename = "input.wav"
                    print("Ask away:")
                    with sr.Microphone() as source:
                        recognizer = sr.Recognizer()
                        source.pause_threshold = 1
                        audio = recognizer.listen(source, phrase_time_limit=None, timeout=None)
                        with open(filename, "wb") as f:
                            f.write(audio.get_wav_data())

                        # Transcribe
                        text = transcribe_audio_to_text(filename)
                        if text:
                            print(f"You said: {text}")

                            # generate
                            response = generate_response(text)
                            print(f"GPT says: {response}")
            except Exception as e:
                print("An error occurred: {}".format(e))

if __name__ == "__main__":
    main()
# Out:
# Say 'Hello' to start
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/speech_recognition/__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_422228/1316925907.py in <module>
#      66
#      67 if __name__ == "__main__":
# ---> 68     main()
#      69
#
# /tmp/ipykernel_422228/1316925907.py in main()
#      38         # Wait for keyword
#      39         print("Say 'Hello' to start ")
# ---> 40         with sr.Microphone() as source:
#      41             recognizer = sr.Recognizer()
#      42             audio = recognizer.listen(source)
#
# ~/.local/lib/python3.10/site-packages/speech_recognition/__init__.py in __init__(self, device_index, sample_rate, chunk_size)
#      78
#      79         # set up PyAudio
# ---> 80         self.pyaudio_module = self.get_pyaudio()
#      81         audio = self.pyaudio_module.PyAudio()
#      82         try:
#
# ~/.local/lib/python3.10/site-packages/speech_recognition/__init__.py in get_pyaudio()
#     108             import pyaudio
#     109         except ImportError:
# --> 110             raise AttributeError("Could not find PyAudio; check installation")
#     111         from distutils.version import LooseVersion
#     112         if LooseVersion(pyaudio.__version__) < LooseVersion("0.2.11"):
#
# AttributeError: Could not find PyAudio; check installation
